# %%
import re; import os; import Bio; from Bio import SeqIO
cwd=os.getcwd()
dir_w_alignments=cwd+'/test_tblastn_data/'
outfilename=cwd+'/test.faa'

with open(outfilename, 'a') as outfile:
    for aln_filename in os.listdir(dir_w_alignments):
        hypothetical_protein=''; exon= ''; new_seqid=''; list_of_used_midpoints=[]; list_of_exons_in_this_hit=[]; total_exons=0; query_length=0; seqcount = 0; start_list=[]; pos=0; exon_dict={}
        if aln_filename.endswith(".aln"):
        
            print('\n********************************\n\nProcessing ' + aln_filename)
            for record in SeqIO.parse(dir_w_alignments + aln_filename, "fasta"):
                seqcount +=1; exon=''; hypothetical_protein=''
                if seqcount == 1: query_length = len(record.seq)## If it's the query sequence, check it's length
                else:
                    list_of_exons_in_this_hit = re.sub("---+","_", str(record.seq)).split('_') ##I consider any AAs separated by more than two gaps as separate exons

                    ### calculate the midpoint position for each exon
                    for exon in list_of_exons_in_this_hit:
                        if exon != '': ###                                #if the exon is not empty, use it
                            start_pos=record.seq.find(exon)#              #find starting_position for exon
                            exon = exon.replace('*', '').replace('-','')  #remove stop codons and gaps
                            half_length=len(exon)/2                       #; print(half_length)
                            midpoint=start_pos+half_length                #; print(str(midpoint))
                            if midpoint not in list_of_used_midpoints:
                                exon_dict[midpoint]=exon                      #Save to dictionary {midpoint:exon}
                                list_of_used_midpoints.append(midpoint)
                            else:
                                print('This exon is redundant and wont be concatenated to any other exons')
                                new_seq_id=aln_filename.replace('.aln','')+'b_1exons'; hypothetical_protein=exon
                                outfile.write('>'+new_seq_id+'\n'+hypothetical_protein+'\n')
                                hypothetical_protein=''

            ### sort the exons in order by their midpoints
            exon_midpoints_ordered_list=sorted(exon_dict.keys())
            for key in exon_midpoints_ordered_list:
                hypothetical_protein = hypothetical_protein + exon_dict[key] ## concatenate exons in the right order
    
            ### How many exons in total?
            total_exons = len(exon_dict); print('Total exons:' + str(total_exons))
    
            ### check how long the hypothetical protein is compared to the query protein
            print('Query length: ' + str(query_length) + '\n' + 'Aligned AA length:' + str(len(hypothetical_protein)))

            ### print that seqid and protein
            new_seq_id=aln_filename.replace('.aln','')+'_'+str(total_exons)+'exons'
        
            outfile.write('>'+new_seq_id+'\n'+hypothetical_protein+'\n')
# Out:
# ********************************
#
# Processing Chlorella_sorokiniana-ASM311615v1-strain_1412-PKFD01000027.aln
# Total exons:5
# Query length: 289
# Aligned AA length:290
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM678297v1-strain_NJ7-RRZL01000054.aln
# Total exons:4
# Query length: 163
# Aligned AA length:168
#
# ********************************
#
# Processing Chlorella_sp-ASM992835v1-strain_CH2018-VIYQ01004964.aln
# Total exons:3
# Query length: 129
# Aligned AA length:119
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM678297v1-strain_NJ7-RRZL01000082.aln
# Total exons:12
# Query length: 392
# Aligned AA length:421
#
# ********************************
#
# Processing Chlorella_spp-ArM29Bkp_1312-strain_ArM0029B-JTEE01000180.aln
# Total exons:7
# Query length: 200
# Aligned AA length:268
#
# ********************************
#
# Processing Chlorella_vulgaris-UMT_ChlVul_UMT-M1_strain_unknown-VJNP01000410.aln
# Total exons:2
# Query length: 151
# Aligned AA length:160
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01002480.aln
# Total exons:1
# Query length: 367
# Aligned AA length:360
#
# ********************************
#
# Processing Chlorella_vulgaris-UMT_ChlVul_UMT-M1_strain_unknown-VJNP01000228.aln
# Total exons:6
# Query length: 272
# Aligned AA length:301
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM313072v1-strain_1230-PKFC01000010.aln
# Total exons:10
# Query length: 339
# Aligned AA length:408
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM102112v1-strain_UTEX_395-LDKB01000632.aln
# Total exons:2
# Query length: 108
# Aligned AA length:105
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM311615v1-strain_1412-PKFD01000045.aln
# Total exons:4
# Query length: 154
# Aligned AA length:168
#
# ********************************
#
# Processing Chlorella_sp-ASM306390v1-strain_A99-PCFQ01000013.aln
# Total exons:12
# Query length: 324
# Aligned AA length:422
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM313072v1-strain_1230-PKFC01000007.aln
# Total exons:10
# Query length: 523
# Aligned AA length:514
#
# ********************************
#
# Processing Chlorella_sp-ASM992835v1-strain_CH2018-VIYQ01000433.aln
# Total exons:10
# Query length: 387
# Aligned AA length:446
#
# ********************************
#
# Processing Botryococcus_braunii-B_braunii_Showa_v1-strain_Showa-MVGU01000077.aln
# Total exons:6
# Query length: 296
# Aligned AA length:331
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678298v1-strain_cultivar13-RRZM01000018.aln
# Total exons:3
# Query length: 127
# Aligned AA length:119
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM313072v1-strain_1230-ASM313072v1.aln
# Total exons:20
# Query length: 458
# Aligned AA length:879
#
# ********************************
#
# Processing Chlorella_sp-ASM992835v1-strain_CH2018-VIYQ01004046.aln
# Total exons:2
# Query length: 351
# Aligned AA length:343
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01003277.aln
# Total exons:7
# Query length: 238
# Aligned AA length:254
#
# ********************************
#
# Processing Chlorella_sp-S68-strain_BAC_9706-JABWAE010000199.aln
# Total exons:2
# Query length: 108
# Aligned AA length:105
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678298v1-strain_cultivar13-RRZM01000021.aln
# Total exons:10
# Query length: 310
# Aligned AA length:331
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01016051.aln
# Total exons:2
# Query length: 144
# Aligned AA length:144
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM972021v1-strain_UTEX259-VATW01000007.aln
# Total exons:3
# Query length: 249
# Aligned AA length:249
#
# ********************************
#
# Processing Chlorella_vulgaris-UMT_ChlVul_UMT-M1_strain_unknown-VJNP01000738.aln
# Total exons:1
# Query length: 61
# Aligned AA length:61
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM313072v1-strain_1230-PKFC01000003.aln
# Total exons:3
# Query length: 110
# Aligned AA length:101
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01001881.aln
# Total exons:4
# Query length: 287
# Aligned AA length:270
#
# ********************************
#
# Processing Chlorella_sp-ASM992835v1-strain_CH2018-VIYQ01002801.aln
# Total exons:3
# Query length: 230
# Aligned AA length:240
#
# ********************************
#
# Processing ANZC01004369.aln
# Total exons:11
# Query length: 330
# Aligned AA length:404
#
# ********************************
#
# Processing Chloroidium_sp-ASM433562v1_strain_C-QAXJ01000001.aln
# Total exons:7
# Query length: 332
# Aligned AA length:347
#
# ********************************
#
# Processing Auxenochlorella_protothecoides-AuxProt1.0-strain_UTEX_2341-MUYL01000884.aln
# Total exons:1
# Query length: 86
# Aligned AA length:84
#
# ********************************
#
# Processing Botryococcus_braunii-B_braunii_Showa_v1-strain_Showa_KV908349.1.aln
# Total exons:6
# Query length: 296
# Aligned AA length:331
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM102112v1-strain_UTEX_395-LDKB01000203.aln
# Total exons:3
# Query length: 249
# Aligned AA length:249
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678298v1-strain_cultivar13-RRZM01000012.aln
# Total exons:9
# Query length: 370
# Aligned AA length:390
#
# ********************************
#
# Processing ANZC01001787.aln
# Total exons:4
# Query length: 194
# Aligned AA length:196
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01003679.aln
# Total exons:4
# Query length: 274
# Aligned AA length:249
#
# ********************************
#
# Processing Chlorella_spp-ArM29Bkp_1312-strain_ArM0029B-JTEE01000072.aln
# Total exons:4
# Query length: 228
# Aligned AA length:230
#
# ********************************
#
# Processing Chlorella_sp-S68-strain_BAC_9706-JABWAE010000195.aln
# Total exons:1
# Query length: 52
# Aligned AA length:52
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01014139.aln
# Total exons:4
# Query length: 244
# Aligned AA length:245
#
# ********************************
#
# Processing Chlorella_sp-S68-strain_BAC_9706-JABWAE010000191.aln
# Total exons:1
# Query length: 277
# Aligned AA length:275
#
# ********************************
#
# Processing Chloroidium_sp-ASM433561v1-strain_JM-QAXI01000449.aln
# Total exons:6
# Query length: 281
# Aligned AA length:296
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678296v1-strain_cultivar07-RRZN01000020.aln
# Total exons:3
# Query length: 110
# Aligned AA length:101
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM311615v1-strain_1412-PKFD01000048.aln
# Total exons:13
# Query length: 330
# Aligned AA length:402
#
# ********************************
#
# Processing Chlorella_sp-ASM306390v1-strain_A99-PCFQ01000037.aln
# Total exons:7
# Query length: 263
# Aligned AA length:341
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678296v1-strain_cultivar07-RRZN01000021.aln
# Total exons:6
# Query length: 471
# Aligned AA length:476
#
# ********************************
#
# Processing Chlorella_sorokiniana-CSI_1228-strain_1228-PQAU01000053.aln
# Total exons:8
# Query length: 296
# Aligned AA length:314
#
# ********************************
#
# Processing Auxenochlorella_protothecoides-AuxProt1.0-strain_UTEX_2341-MUYL01001858.aln
# Total exons:5
# Query length: 276
# Aligned AA length:277
#
# ********************************
#
# Processing Chlorella_spp-ArM29Bkp_1312-strain_ArM0029B-JTEE01000038.aln
# Total exons:2
# Query length: 165
# Aligned AA length:166
#
# ********************************
#
# Processing Chlorella_sorokiniana-CSI_1228-strain_1228-PQAU01000021.aln
# Total exons:9
# Query length: 395
# Aligned AA length:423
#
# ********************************
#
# Processing Auxenochlorella_protothecoides-AuxProt1.0-strain_UTEX_2341-MUYL01000614.aln
# This exon is redundant and wont be concatenated to any other exons
# Total exons:1
# Query length: 170
# Aligned AA length:170
#
# ********************************
#
# Processing Chlorella_sorokiniana-ASM678296v1-strain_cultivar07-RRZN01000051.aln
# Total exons:8
# Query length: 316
# Aligned AA length:343
#
# ********************************
#
# Processing ANZC01000360.aln
# Total exons:3
# Query length: 228
# Aligned AA length:229
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM972021v1-strain_UTEX259-VATW01000054.aln
# Total exons:1
# Query length: 277
# Aligned AA length:275
#
# ********************************
#
# Processing Auxenochlorella_protothecoides-AuxProt1.0-strain_UTEX_2341-MUYL01000375.aln
# This exon is redundant and wont be concatenated to any other exons
# Total exons:1
# Query length: 170
# Aligned AA length:170
#
# ********************************
#
# Processing Chlorella_sp-ASM306390v1-strain_A99-PCFQ01000081.aln
# Total exons:1
# Query length: 50
# Aligned AA length:50
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM678297v1-strain_NJ7-RRZL01000059.aln
# Total exons:4
# Query length: 232
# Aligned AA length:240
#
# ********************************
#
# Processing Chlorella_sp-ASM433573v1-strain_KRBP-QAXK01011810.aln
# Total exons:2
# Query length: 116
# Aligned AA length:116
#
# ********************************
#
# Processing Chlorella_vulgaris-ASM102112v1-strain_UTEX_395-LDKB01000106.aln
# Total exons:1
# Query length: 277
# Aligned AA length:275

# %%
# Out:
# /Users/gregory/Desktop/scripts_for_DecelleLab/exon_stitcher
